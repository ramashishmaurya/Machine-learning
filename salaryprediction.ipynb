# %%
import seaborn as sns 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('D:/datasets/jobsalary.csv')

# %%
df.head()
# Out:
#             job_title  experience_years education_level  skills_count  \
# 0         AI Engineer                10        Bachelor             2
# 1        Data Analyst                 5        Bachelor            17
# 2  Frontend Developer                18             PhD             4
# 3    Business Analyst                19             PhD            13
# 4     Product Manager                15        Bachelor             7
#
#         industry company_size   location remote_work  certifications  salary
# 0     Healthcare       Medium      India      Hybrid               2  109413
# 1        Telecom        Small  Australia          No               0   93764
# 2          Media       Medium  Singapore          No               1  148123
# 3         Retail       Medium     Canada         Yes               0  189123
# 4  Manufacturing        Large     Sweden         Yes               0  165069

# %%
df.shape
# Out:
# (250000, 10)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   job_title         250000 non-null  str
#  1   experience_years  250000 non-null  int64
#  2   education_level   250000 non-null  str
#  3   skills_count      250000 non-null  int64
#  4   industry          250000 non-null  str
#  5   company_size      250000 non-null  str
#  6   location          250000 non-null  str
#  7   remote_work       250000 non-null  str
#  8   certifications    250000 non-null  int64
#  9   salary            250000 non-null  int64
# dtypes: int64(4), str(6)
# memory usage: 19.1 MB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
abc = df['job_title'].value_counts()

# %%
df['job_title'].value_counts().sort_values().plot(kind='barh')
# Out:
# <Axes: ylabel='job_title'>

# %%
df['job_title'].value_counts().sort_values().plot(
    kind='barh',
    figsize=(8,5),
    color='skyblue',
    grid=True,
    title='Job Profile Count'
)

plt.xlabel("Count")
plt.ylabel("Job Role")
plt.show()

# %%
df.sample(3)
# Out:
#                  job_title  experience_years education_level  skills_count  \
# 27271       Data Scientist                 0        Bachelor            11
# 194109   Software Engineer                14             PhD            13
# 106197  Frontend Developer                 3          Master            16
#
#           industry company_size location remote_work  certifications  salary
# 27271      Finance        Small      USA         Yes               2  132444
# 194109      Retail      Startup   Canada         Yes               1  171202
# 106197  Healthcare        Small   Canada      Hybrid               3  146099

# %%
df.columns
# Out:
# Index(['job_title', 'experience_years', 'education_level', 'skills_count',
#        'industry', 'company_size', 'location', 'remote_work', 'certifications',
#        'salary'],
#       dtype='str')

# %%
df.groupby('location')['salary'].median()
# Out:
# location
# Australia      137753.5
# Canada         165474.0
# Germany        151538.0
# India           96501.0
# Netherlands    137356.0
# Remote         137836.0
# Singapore      137699.0
# Sweden         138033.0
# UK             158191.0
# USA            179647.0
# Name: salary, dtype: float64

# %%
df.groupby('job_title')['experience_years'].mean()
# Out:
# job_title
# AI Engineer                   9.997422
# Backend Developer             9.987077
# Business Analyst             10.063251
# Cloud Engineer               10.023591
# Cybersecurity Analyst         9.987643
# Data Analyst                 10.001062
# Data Scientist               10.098947
# DevOps Engineer              10.002872
# Frontend Developer            9.882906
# Machine Learning Engineer     9.977705
# Product Manager              10.019809
# Software Engineer            10.021891
# Name: experience_years, dtype: float64

# %%
x = df.drop('salary' ,axis=1)

# %%
x
# Out:
#                  job_title  experience_years education_level  skills_count  \
# 0              AI Engineer                10        Bachelor             2
# 1             Data Analyst                 5        Bachelor            17
# 2       Frontend Developer                18             PhD             4
# 3         Business Analyst                19             PhD            13
# 4          Product Manager                15        Bachelor             7
# ...                    ...               ...             ...           ...
# 249995   Software Engineer                17             PhD             2
# 249996  Frontend Developer                20             PhD             7
# 249997    Business Analyst                 1        Bachelor            12
# 249998      Data Scientist                 0     High School             2
# 249999        Data Analyst                16         Diploma             2
#
#              industry company_size   location remote_work  certifications
# 0          Healthcare       Medium      India      Hybrid               2
# 1             Telecom        Small  Australia          No               0
# 2               Media       Medium  Singapore          No               1
# 3              Retail       Medium     Canada         Yes               0
# 4       Manufacturing        Large     Sweden         Yes               0
# ...               ...          ...        ...         ...             ...
# 249995        Telecom   Enterprise      India          No               1
# 249996        Telecom      Startup     Remote          No               2
# 249997         Retail   Enterprise      India         Yes               0
# 249998     Consulting        Small     Sweden      Hybrid               5
# 249999     Technology       Medium         UK          No               5
#
# [250000 rows x 9 columns]

# %%
y = df[['salary']]

# %%
y
# Out:
#         salary
# 0       109413
# 1        93764
# 2       148123
# 3       189123
# 4       165069
# ...        ...
# 249995  127791
# 249996  154593
# 249997   75988
# 249998   90467
# 249999  133084
#
# [250000 rows x 1 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression

# %%
categorical_features = [
    'job_title', 'education_level', 'industry',
    'company_size', 'location', 'remote_work'
]

numeric_features = [
    'experience_years', 'skills_count', 'certifications'
]

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)
    ],
    remainder='passthrough'
)

# %%
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['job_title',
#                                                    'education_level',
#                                                    'industry', 'company_size',
#                                                    'location',
#                                                    'remote_work'])])),
#                 ('regressor', LinearRegression())])

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, r2_score

print("MAE:", mean_absolute_error(y_test, y_pred))
print("R2 Score:", r2_score(y_test, y_pred))
# Out:
# MAE: 5488.540337271715
# R2 Score: 0.9630048141670783

# %%
import joblib

joblib.dump(model, "model.pkl")
# Out:
# ['model.pkl']

# %%
df.columns
# Out:
# Index(['job_title', 'experience_years', 'education_level', 'skills_count',
#        'industry', 'company_size', 'location', 'remote_work', 'certifications',
#        'salary'],
#       dtype='str')

# %%
abc
# Out:
# job_title
# Backend Developer            21125
# Cybersecurity Analyst        20959
# Product Manager              20950
# AI Engineer                  20945
# Data Scientist               20890
# DevOps Engineer              20889
# Software Engineer            20876
# Data Analyst                 20722
# Cloud Engineer               20686
# Machine Learning Engineer    20677
# Business Analyst             20648
# Frontend Developer           20633
# Name: count, dtype: int64
