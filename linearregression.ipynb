# %%
import pandas  as pd 
import numpy as np

# %%
df = pd.read_csv('linear.csv' , index_col=False)

# %%
df.head()
# Out:
#    YearsExperience  Salary
# 0                1   32000
# 1                2   35000
# 2                3   40000
# 3                4   45000
# 4                5   52000

# %%
import seaborn as sns

# %%
sns.scatterplot(data= df , x='YearsExperience' , y='Salary')
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
linear = LinearRegression()

# %%
x = df[['YearsExperience']]

# %%
y = df[['Salary']]

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size=0.3 )

# %%
result = linear.fit(x_train , y_train)

# %%
y_pre = result.predict(x_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error

# %%
mean_squared_error(y_test , y_pre)
# Out:
# 369579815.35109985

# %%
r2_score(y_test , y_pre)
# Out:
# 0.992583682635095

# %%
# Out:
# array([[141739.98351195],
#        [135769.16735367],
#        [ 93973.45424567],
#        [105915.08656224],
#        [ 88002.63808739],
#        [ 99944.27040396]])

# %%
import numpy as np

# %%
predict.shape
# Out:
# (1, 1)

# %%
predict = np.array([4]).reshape(-1, 1)

# %%
predict
# Out:
# array([[4]])

# %%
result.predict(predict)
# Out:
# E:\anaconda\envs\ml\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[46206.92497939]])

# %%
result.coef_
# Out:
# array([[5970.81615829]])

# %%
result.intercept_
# Out:
# array([22323.66034625])

# %%
b = 5970.81615829*4 + 22323.66034625

# %%
b
# Out:
# 46206.92497941

# %%
y = mx + c  this
